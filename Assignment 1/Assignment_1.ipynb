# %% [markdown]
# # Assignment 1

# %% [markdown]
# Link to the github repo - https://github.com/manya16400/CS-6980-Computer-Vision/tree/main/Assignment%201

# %% [markdown]
# # Part A : Camera Calibration

# %% [markdown]
# ## 1.

# %%
# !python 1_code.py
# Out:
# image found : 25
# 01_data\16644200529294.jpeg
# True
# 01_data\16644200530310.jpeg
# True
# 01_data\16644200530909.jpeg
# True
# 01_data\16644200532008.jpeg
# True
# 01_data\16644200532983.jpeg
# True
# 01_data\16644200533425.jpeg
# True
# 01_data\16644200534356.jpeg
# True
# 01_data\16644200535393.jpeg
# True
# 01_data\16644200536289.jpeg
# True
# 01_data\16644200536854.jpeg
# True
# 01_data\16644200537775.jpeg
# True
# 01_data\16644200538474.jpeg
# True
# 01_data\16644200539346.jpeg
# True
# 01_data\16644200540188.jpeg
# True
# 01_data\16644200540957.jpeg
# True
# 01_data\16644200541855.jpeg
# True
# 01_data\16644200542694.jpeg
# True
# 01_data\16644200543508.jpeg
# True
# 01_data\16644200544354.jpeg
# True
# 01_data\16644200545204.jpeg
# True
# 01_data\16644200546231.jpeg
# True
# 01_data\16644200546860.jpeg
# True
# 01_data\16644200547704.jpeg
# True
# 01_data\16644200548523.jpeg
# True
# Number of images used for calliberation: 24
# 0.5838210730863993
# intrinsic matrix:
# ...

# %% [markdown]
# # Part B : Python Prototyping

# %% [markdown]
# ## 2.

# %% [markdown]
# Image used for the prototype is - <br>
# ![16647607724546.jpeg](attachment:16647607724546.jpeg)

# %%
# !python 2_code.py
# Out:
# The two (x,y) image points for the length of cuboid are :
# 879 , 123
# 852 , 864
# Length of cuboid from image points:  741.4917396707801
# Length of cuboid from world points:  969.2744382787693

# %% [markdown]
# # Part C : Application Development

# %% [markdown]
# ## 3.

# %% [markdown]
# Yes, it is feasible to show a RGB stream from the mono camera and a depth map stream from the stereo camera simultaneously. The screen recording of the output is stored in OneDrive : https://studentgsu-my.sharepoint.com/:v:/g/personal/mrampuria1_student_gsu_edu/EYaJK-Io8IJLkI23Yc0wn_QBHFDgKsXu7_wKvi1ZAI5ngg?e=RGSC2q

# %%
# !python 3_code.py
# Out:
# [184430100128900E00] [1.1] [3152.787] [system] [warning] ColorCamera IMX214: capping FPS for selected resolution to 35
# [184430100128900E00] [1.1] [3152.787] [system] [warning] MonoCamera OV7251: capping FPS for selected resolution to 117
# FPS : 0.0
# FPS : 0.0
# FPS : 187.49999996180122
# FPS : 124.999999988745
# FPS : 106.38297871820008
# FPS : 95.23809523519145
# FPS : 88.60759493497876
# FPS : 85.10638297785384
# FPS : 81.81818181774887
# FPS : 80.0
# FPS : 78.01418439535959
# FPS : 76.43312101770557
# FPS : 82.80254776918103
# FPS : 89.1719745206565
# FPS : 95.54140127213196
# FPS : 93.02325581271
# FPS : 98.83720930100438
# FPS : 104.65116278929875
# FPS : 101.06382978620144
# FPS : 28.409090909028663
# FPS : 29.20723226699854
# FPS : 29.93197278909194
# FPS : 31.29251700677794
# FPS : 32.65306122446394
# FPS : 33.333333333333336
# FPS : 34.666666666666664
# FPS : 36.0
# FPS : 36.553524804022
# FPS : 37.85900783273707
# FPS : 39.16449086145214
# FPS : 40.46997389016721
# ...

# %% [markdown]
# ## 4.

# %% [markdown]
# I ran the Depthai Camera Calibration tutorial and found out the intrinsic and distortion matrices. <br> Below is the screenshot of comparison of the matrices obtained from Part A Q1 (left side) and the depthai tutorial (right side command prompt). <br>

# %% [markdown]
# ![Screenshot%20%2830%29.png](attachment:Screenshot%20%2830%29.png)

# %% [markdown]
# __The intrinsic matrix obtained from Part A Q1 :__ <br> [[2.98425233e+03 0.00000000e+00 1.50013617e+03] <br>
#  [0.00000000e+00 2.98045576e+03 6.43681979e+02] <br>
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00]] <br>
#
# __The intrinsic matrix obtained from Depthai Camera tutorial :__ <br>
# [[1.48961778e+03 0.00000000e+00 9.59250000e+03] <br>
#  [0.00000000e+00 1.48773309+03 5.392500000+02] <br>
#  [0.00000000e+00 0.00000000e+00 1.00000000e+00]]
